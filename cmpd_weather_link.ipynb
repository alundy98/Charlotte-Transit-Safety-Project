# %%
import pandas as pd
import numpy as np
import requests
import time
import os
import re
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("WEATHER_API_KEY")
df = pd.read_csv("data\\crime_within_station_walksheds.csv")

# %%
def fetch_daily_weather(lat, lon, date_str, unitGroup="us"):
    """
    Returns a dict with daily summary weather for a single (lat, lon, date).
    """
    base = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline"
    location = f"{lat},{lon}"
    url = f"{base}/{location}/{date_str}"

    params = {
        "key": API_KEY,
        "contentType": "json",
        "unitGroup": unitGroup,
        "include": "days",
        # Request only what you need (plus datetime for safety)
        "elements": ",".join([
            "datetime",
            "tempmax",
            "tempmin",
            "temp",
            "precip",
            "precipcover",
            "cloudcover",
            "humidity",
            "windspeed",
            "windgust",
            "visibility",
            "snow",
            "conditions"
])

    }

    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()

    # Daily summary lives in data["days"][0] for a single-day query
    day = data["days"][0]
    return {
        "DATE_REPORTED": day.get("datetime"),
        "tempmax": day.get("tempmax"),
        "tempmin": day.get("tempmin"),
        "temp": day.get("temp"),
        "precip": day.get("precip"),
        "precipcover": day.get("precipcover"),
        "cloudcover": day.get("cloudcover"),
        "humidity": day.get("humidity"),
        "windspeed": day.get("windspeed"),
        "windgust": day.get("windgust"),
        "visibility": day.get("visibility"),
        "snow": day.get("snow"),
        "conditions": day.get("conditions"),
    }

# %%
df["date"] = pd.to_datetime(df["date"]).dt.strftime("%Y-%m-%d")

# Optional: reduce unique calls by rounding coords
df["LATITUDE_PUBLIC"] = df["LATITUDE_PUBLIC"].round(2)
df["LONGITUDE_PUBLIC"] = df["LONGITUDE_PUBLIC"].round(2)

keys = df[["date", "LATITUDE_PUBLIC", "LONGITUDE_PUBLIC"]].drop_duplicates()

# %%
weather_rows = []
for i, row in keys.iterrows():
    try:
        w = fetch_daily_weather(row["LATITUDE_PUBLIC"], row["LONGITUDE_PUBLIC"], row["date"])
        w["LATITUDE_PUBLIC"] = row["LATITUDE_PUBLIC"]
        w["LONGITUDE_PUBLIC"] = row["LONGITUDE_PUBLIC"]
        weather_rows.append(w)
    except Exception as e:
        # Keep going; log failures
        print(e)
        weather_rows.append({
            "INCIDENT_REPORT_ID": row["INCIDENT_REPORT_ID"],
            "LATITUDE_PUBLIC": row["LATITUDE_PUBLIC"],
            "LONGITUDE_PUBLIC": row["LONGITUDE_PUBLIC"],
            "tempmax": None,
            "tempmin": None,
            "temp": None,
            "precip": None,
            "precipcover": None,
            "cloudcover": None,
            "humidity": None,
            "windspeed": None,
            "windgust": None,
            "visibility": None,
            "snow": None,
            "conditions": None,
            "error": str(e)[:200]
        })

    # simple rate-limiting to be safe
    time.sleep(0.1)
    if i % 100 == 0:
        print(i)

weather_df = pd.DataFrame(weather_rows)
# Out:
# 0
# 200
# 300
# 400
# 600
# 900
# 1500
# 1600
# 2100
# 2200
# 2800
# 2900
# 3100
# 3200
# 3300
# 3400
# 3500
# 3700
# 3800
# 3900
# 4100
# 4200
# 4300
# 4500
# 4600
# 5000
# 5100
# 5300
# 5400
# 5500
# 5600
# 5800
# 6100
# 6300
# 6400
# 6500
# 6600
# 6700
# 7000
# 7100
# 7300
# 7800
# 7900
# 8300
# 8600
# 8700
# 9600
# 9800
# 9900
# 10000
# 10100
# 10400
# 10500
# 11200
# 11500
# 11600
# 12000
# 12200
# 12300
# 12900
# 13300
# 13400
# 13600
# 13800
# 14100
# 14800
# 14900
# 15100
# 15200
# 16700
# 16800
# 17100
# 17200
# 17600
# 17800
# 18500
# 19000
# 19200
# 19300
# 19400
# 20600
# 21400
# 21600
# 22700
# 23000
# 23200
# 24200
# 24600
# 24800
# 24900
# 25000
# 25400
# 25500
# 25900
# 26300
# 26800
# 27400
# 27700
# 28100
# 28400
# 28600
# 29300
# 30700
# 31200
# 31500
# 32100
# 32800
# 33800
# 34100
# 34200
# 34300
# 34500
# 35100
# 35700
# 36600
# 37300
# 37600
# 38400
# 39600
# 40300
# 40600
# 40900
# 41800
# 42500
# 43200
# 44000
# 44200
# 44400
# 45300
# 45900
# 46900
# 47000
# 48000
# 50400
# 52600
# 53200
# 53900
# 56000
# 57500
# 58100
# 58200
# 58800
# 60200
# 60700
# 61600
# 61700

# %%
weather_df.rename(columns={"DATE_REPORTED": "date"}, inplace=True)

# %%
df_complete = df.merge(weather_df, on=["date", "LATITUDE_PUBLIC", "LONGITUDE_PUBLIC"], how="left")

# %%
df_complete.isna().sum()
# Out:
# INCIDENT_REPORT_ID               0
# LOCATION                         0
# ZIP                              0
# LATITUDE_PUBLIC                  0
# LONGITUDE_PUBLIC                 0
# CMPD_PATROL_DIVISION           302
# NPA                              0
# LOCATION_TYPE_DESCRIPTION        0
# PLACE_TYPE_DESCRIPTION           0
# PLACE_DETAIL_DESCRIPTION         0
# HIGHEST_NIBRS_DESCRIPTION        0
# date                             0
# year                             0
# hour                             0
# day_type                         0
# cluster                          0
# cluster_title                    0
# geometry                         0
# index_right                      0
# name                             0
# lat                              0
# lon                              0
# tempmax                          0
# tempmin                          0
# temp                             0
# precip                           0
# precipcover                      0
# cloudcover                       0
# humidity                         0
# windspeed                        0
# windgust                     12063
# visibility                       0
# snow                             0
# conditions                       0
# dtype: int64

# %%
df_complete.head(20)
# Out:
#    INCIDENT_REPORT_ID            LOCATION    ZIP  LATITUDE_PUBLIC  \
# 0    20220704-0820-00    300 S BREVARD ST  28202            35.22
# 1    20220704-0820-00    300 S BREVARD ST  28202            35.22
# 2    20220704-0820-00    300 S BREVARD ST  28202            35.22
# 3    20230104-1325-00      400 S TRYON ST  28202            35.22
# 4    20230104-1325-00      400 S TRYON ST  28202            35.22
# 5    20180916-0854-01      900 SPINDLE ST  28206            35.23
# 6    20180523-1548-04      600 S TRYON ST  28202            35.22
# 7    20191125-1133-02      200 E BLAND ST  28203            35.22
# 8    20230428-1602-03     600 N CHURCH ST  28202            35.23
# 9    20240703-0652-00   500 N DAVIDSON ST  28202            35.23
# 10   20260118-0023-00  500 NORTH ELLIS LN  28202            35.23
# 11   20260118-0023-00  500 NORTH ELLIS LN  28202            35.23
# 12   20240229-1100-01       1300 SOUTH BV  28203            35.22
# 13   20170215-2050-03    300 S COLLEGE ST  28202            35.22
# 14   20170215-2050-03    300 S COLLEGE ST  28202            35.22
# 15   20170215-2050-03    300 S COLLEGE ST  28202            35.22
# 16   20260112-0720-00       2000 SOUTH BV  28203            35.21
# 17   20221109-0754-01    200 N COLLEGE ST  28202            35.23
# 18   20221109-0754-01    200 N COLLEGE ST  28202            35.23
# 19   20221109-0754-01    200 N COLLEGE ST  28202            35.23
#
#     LONGITUDE_PUBLIC CMPD_PATROL_DIVISION  NPA LOCATION_TYPE_DESCRIPTION  \
# 0             -80.84              Central  476                  Outdoors
# 1             -80.84              Central  476                  Outdoors
# 2             -80.84              Central  476                  Outdoors
# 3             -80.85              Central  476                  Outdoors
# 4             -80.85              Central  476                  Outdoors
# 5             -80.83              Central  476                   Indoors
# 6             -80.85              Central  476                  Outdoors
# 7             -80.85              Central    3                     Other
# 8             -80.84              Central  476              Parking Deck
# 9             -80.83              Central  476                   Indoors
# 10            -80.84              Central  476                   Indoors
# 11            -80.84              Central  476                   Indoors
# 12            -80.85              Central    3                   Indoors
# 13            -80.84              Central  476                   Indoors
# 14            -80.84              Central  476                   Indoors
# 15            -80.84              Central  476                   Indoors
# 16            -80.86              Central    3                   Indoors
# 17            -80.84              Central  476                  Outdoors
# 18            -80.84              Central  476                  Outdoors
# 19            -80.84              Central  476                  Outdoors
#
#     PLACE_TYPE_DESCRIPTION           PLACE_DETAIL_DESCRIPTION  ...  temp  \
# 0                Open Area                     Street/Highway  ...  80.4
# 1                Open Area                     Street/Highway  ...  80.4
# 2                Open Area                     Street/Highway  ...  80.4
# 3         Commercial Place           Other - Commercial Place  ...  61.3
# 4         Commercial Place           Other - Commercial Place  ...  61.3
# 5              Residential                  Private Residence  ...  72.9
# 6                Open Area                  Construction Site  ...  77.6
# 7         Commercial Place               Bar/Tavern/Nightclub  ...  46.1
# 8              Residential       Apartment/Duplex Private Res  ...  67.8
# 9              Residential       Apartment/Duplex Private Res  ...  80.1
# 10        Commercial Place       Restaurant/Diner/Coffee Shop  ...  39.5
# 11        Commercial Place       Restaurant/Diner/Coffee Shop  ...  39.5
# 12        Commercial Place           Other - Commercial Place  ...  45.2
# 13        Commercial Place       Restaurant/Diner/Coffee Shop  ...  51.1
# 14        Commercial Place       Restaurant/Diner/Coffee Shop  ...  51.1
# 15        Commercial Place       Restaurant/Diner/Coffee Shop  ...  51.1
# 16                  Retail                      Shopping Mall  ...  37.3
# 17  Public/Non-Residential  Dock/Wharf/Freight/Modal Terminal  ...  56.1
# 18  Public/Non-Residential  Dock/Wharf/Freight/Modal Terminal  ...  56.1
# 19  Public/Non-Residential  Dock/Wharf/Freight/Modal Terminal  ...  56.1
#
#    precip  precipcover  cloudcover humidity  windspeed windgust visibility  \
# 0   0.011         8.33        53.2     76.0       14.5     20.8        9.4
# 1   0.011         8.33        53.2     76.0       14.5     20.8        9.4
# 2   0.011         8.33        53.2     76.0       14.5     20.8        9.4
# 3   1.307        50.00        89.5     93.3       12.8     32.9        8.3
# 4   1.307        50.00        89.5     93.3       12.8     32.9        8.3
# 5   3.875       100.00        99.5     97.1       25.5     39.8        3.5
# 6   0.000         0.00        74.8     76.5       10.0      NaN        9.9
# 7   0.000         0.00         4.8     69.5        6.5      NaN        9.8
# 8   0.844        25.00        78.8     77.1       14.2     32.9        9.1
# 9   0.000         0.00        59.8     58.3        6.3     13.0        9.9
# 10  0.268        54.17        47.9     83.0       12.2     20.8        8.2
# 11  0.268        54.17        47.9     83.0       12.2     20.8        8.2
# 12  0.000         0.00        58.3     32.2       12.3     19.0        9.9
# 13  0.422        16.67        54.6     54.3       15.5     27.4        9.3
# 14  0.422        16.67        54.6     54.3       15.5     27.4        9.3
# 15  0.422        16.67        54.6     54.3       15.5     27.4        9.3
# 16  0.000         0.00        12.3     47.3        7.7     16.3        9.9
# 17  0.000         0.00        57.4     50.5       17.9     31.1        9.9
# 18  0.000         0.00        57.4     50.5       17.9     31.1        9.9
# 19  0.000         0.00        57.4     50.5       17.9     31.1        9.9
#
#     snow              conditions
# 0    0.0  Rain, Partially cloudy
# 1    0.0  Rain, Partially cloudy
# 2    0.0  Rain, Partially cloudy
# 3    0.0  Rain, Partially cloudy
# 4    0.0  Rain, Partially cloudy
# 5    0.0          Rain, Overcast
# 6    0.0        Partially cloudy
# 7    0.0                   Clear
# 8    0.0  Rain, Partially cloudy
# 9    0.0        Partially cloudy
# 10   0.2  Rain, Partially cloudy
# 11   0.2  Rain, Partially cloudy
# 12   0.0        Partially cloudy
# 13   0.0  Rain, Partially cloudy
# 14   0.0  Rain, Partially cloudy
# 15   0.0  Rain, Partially cloudy
# 16   0.0                   Clear
# 17   0.0        Partially cloudy
# 18   0.0        Partially cloudy
# 19   0.0        Partially cloudy
#
# [20 rows x 34 columns]

# %%
df_complete['snow'] = df_complete['snow'].fillna(0)
df_complete.dropna(subset=['temp'], inplace=True)
df_complete.drop(columns=['windgust'], inplace=True)
df_complete.isna().sum()
# Out:
# INCIDENT_REPORT_ID             0
# LOCATION                       0
# ZIP                            0
# LATITUDE_PUBLIC                0
# LONGITUDE_PUBLIC               0
# CMPD_PATROL_DIVISION         302
# NPA                            0
# LOCATION_TYPE_DESCRIPTION      0
# PLACE_TYPE_DESCRIPTION         0
# PLACE_DETAIL_DESCRIPTION       0
# HIGHEST_NIBRS_DESCRIPTION      0
# date                           0
# year                           0
# hour                           0
# day_type                       0
# cluster                        0
# cluster_title                  0
# geometry                       0
# index_right                    0
# name                           0
# lat                            0
# lon                            0
# tempmax                        0
# tempmin                        0
# temp                           0
# precip                         0
# precipcover                    0
# cloudcover                     0
# humidity                       0
# windspeed                      0
# visibility                     0
# snow                           0
# conditions                     0
# dtype: int64

# %%
df_complete.to_csv("data\\crime_with_weather.csv", index=False)

# %%
import pandas as pd
import requests
import time
import os
import dotenv
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("WEATHER_API_KEY")
df = pd.read_csv("data\\crime_within_station_walksheds.csv")

# %%
def fetch_daily_weather(lat, lon, date_str, unitGroup="us"):
    """
    Returns a dict with daily summary weather for a single (lat, lon, date).
    """
    base = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline"
    location = f"{lat},{lon}"
    url = f"{base}/{location}/{date_str}"

    params = {
        "key": API_KEY,
        "contentType": "json",
        "unitGroup": unitGroup,
        "include": "days",
        # Request only what you need (plus datetime for safety)
        "elements": ",".join([
            "datetime",
            "tempmax",
            "tempmin",
            "temp",
            "precip",
            "precipcover",
            "cloudcover",
            "humidity",
            "windspeed",
            "windgust",
            "visibility",
            "snow",
            "conditions"
])

    }

    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()

    # Daily summary lives in data["days"][0] for a single-day query
    day = data["days"][0]
    return {
        "DATE_REPORTED": day.get("datetime"),
        "tempmax": day.get("tempmax"),
        "tempmin": day.get("tempmin"),
        "temp": day.get("temp"),
        "precip": day.get("precip"),
        "precipcover": day.get("precipcover"),
        "cloudcover": day.get("cloudcover"),
        "humidity": day.get("humidity"),
        "windspeed": day.get("windspeed"),
        "windgust": day.get("windgust"),
        "visibility": day.get("visibility"),
        "snow": day.get("snow"),
        "conditions": day.get("conditions"),
    }

# %%
df["DATE_REPORTED"] = pd.to_datetime(df["DATE_REPORTED"]).dt.strftime("%Y-%m-%d")

# Optional: reduce unique calls by rounding coords
df["LATITUDE_PUBLIC"] = df["LATITUDE_PUBLIC"].round(2)
df["LONGITUDE_PUBLIC"] = df["LONGITUDE_PUBLIC"].round(2)

keys = df[["DATE_REPORTED", "LATITUDE_PUBLIC", "LONGITUDE_PUBLIC"]].drop_duplicates()

# %%
weather_rows = []
for i, row in keys.iterrows():
    try:
        w = fetch_daily_weather(row["LATITUDE_PUBLIC"], row["LONGITUDE_PUBLIC"], row["DATE_REPORTED"])
        w["LATITUDE_PUBLIC"] = row["LATITUDE_PUBLIC"]
        w["LONGITUDE_PUBLIC"] = row["LONGITUDE_PUBLIC"]
        weather_rows.append(w)
    except Exception as e:
        # Keep going; log failures
        print(e)
        weather_rows.append({
            "DATE_REPORTED": row["DATE_REPORTED"],
            "LATITUDE_PUBLIC": row["LATITUDE_PUBLIC"],
            "LONGITUDE_PUBLIC": row["LONGITUDE_PUBLIC"],
            "tempmax": None,
            "tempmin": None,
            "temp": None,
            "precip": None,
            "precipcover": None,
            "cloudcover": None,
            "humidity": None,
            "windspeed": None,
            "windgust": None,
            "visibility": None,
            "snow": None,
            "conditions": None,
            "error": str(e)[:200]
        })

    # simple rate-limiting to be safe
    time.sleep(0.1)
    if i % 1000 == 0:
        print(i)

weather_df = pd.DataFrame(weather_rows)
# Out:
# 0
# 5000
# 7000
# 10000
# 12000
# 19000
# 23000
# 25000
# 44000
# 47000
# 48000
# 56000

# %%
df_complete = df.merge(weather_df, on=["DATE_REPORTED", "LATITUDE_PUBLIC", "LONGITUDE_PUBLIC"], how="left")

# %%
df_complete.isna().sum()
# Out:
# YEAR                             0
# LOCATION                         0
# ZIP                              0
# LATITUDE_PUBLIC                  0
# LONGITUDE_PUBLIC                 0
# CMPD_PATROL_DIVISION           302
# NPA                              0
# DATE_REPORTED                    0
# LOCATION_TYPE_DESCRIPTION        0
# PLACE_TYPE_DESCRIPTION           0
# PLACE_DETAIL_DESCRIPTION         0
# HIGHEST_NIBRS_DESCRIPTION        0
# cluster                          0
# cluster_title                    0
# geometry                         0
# index_right                      0
# name                             0
# lat                              0
# lon                              0
# tempmax                          0
# tempmin                          0
# temp                             0
# precip                           0
# precipcover                      0
# cloudcover                       0
# humidity                         0
# windspeed                        0
# windgust                     12063
# visibility                       0
# snow                             0
# conditions                       0
# dtype: int64

# %%
df_complete.head(20)
# Out:
#     YEAR            LOCATION    ZIP  LATITUDE_PUBLIC  LONGITUDE_PUBLIC  \
# 0   2022    300 S BREVARD ST  28202            35.22            -80.84
# 1   2022    300 S BREVARD ST  28202            35.22            -80.84
# 2   2022    300 S BREVARD ST  28202            35.22            -80.84
# 3   2023      400 S TRYON ST  28202            35.22            -80.85
# 4   2023      400 S TRYON ST  28202            35.22            -80.85
# 5   2018      900 SPINDLE ST  28206            35.23            -80.83
# 6   2018      600 S TRYON ST  28202            35.22            -80.85
# 7   2019      200 E BLAND ST  28203            35.22            -80.85
# 8   2023     600 N CHURCH ST  28202            35.23            -80.84
# 9   2024   500 N DAVIDSON ST  28202            35.23            -80.83
# 10  2026  500 NORTH ELLIS LN  28202            35.23            -80.84
# 11  2026  500 NORTH ELLIS LN  28202            35.23            -80.84
# 12  2024       1300 SOUTH BV  28203            35.22            -80.85
# 13  2017    300 S COLLEGE ST  28202            35.22            -80.84
# 14  2017    300 S COLLEGE ST  28202            35.22            -80.84
# 15  2017    300 S COLLEGE ST  28202            35.22            -80.84
# 16  2026       2000 SOUTH BV  28203            35.21            -80.86
# 17  2022    200 N COLLEGE ST  28202            35.23            -80.84
# 18  2022    200 N COLLEGE ST  28202            35.23            -80.84
# 19  2022    200 N COLLEGE ST  28202            35.23            -80.84
#
#    CMPD_PATROL_DIVISION  NPA DATE_REPORTED LOCATION_TYPE_DESCRIPTION  \
# 0               Central  476    2022-07-04                  Outdoors
# 1               Central  476    2022-07-04                  Outdoors
# 2               Central  476    2022-07-04                  Outdoors
# 3               Central  476    2023-01-04                  Outdoors
# 4               Central  476    2023-01-04                  Outdoors
# 5               Central  476    2018-09-16                   Indoors
# 6               Central  476    2018-05-23                  Outdoors
# 7               Central    3    2019-11-25                     Other
# 8               Central  476    2023-04-28              Parking Deck
# 9               Central  476    2024-07-03                   Indoors
# 10              Central  476    2026-01-18                   Indoors
# 11              Central  476    2026-01-18                   Indoors
# 12              Central    3    2024-02-29                   Indoors
# 13              Central  476    2017-02-15                   Indoors
# 14              Central  476    2017-02-15                   Indoors
# 15              Central  476    2017-02-15                   Indoors
# 16              Central    3    2026-01-12                   Indoors
# 17              Central  476    2022-11-09                  Outdoors
# 18              Central  476    2022-11-09                  Outdoors
# 19              Central  476    2022-11-09                  Outdoors
#
#     PLACE_TYPE_DESCRIPTION  ...  temp precip  precipcover cloudcover humidity  \
# 0                Open Area  ...  80.4  0.011         8.33       53.2     76.0
# 1                Open Area  ...  80.4  0.011         8.33       53.2     76.0
# 2                Open Area  ...  80.4  0.011         8.33       53.2     76.0
# 3         Commercial Place  ...  61.3  1.307        50.00       89.5     93.3
# 4         Commercial Place  ...  61.3  1.307        50.00       89.5     93.3
# 5              Residential  ...  72.9  3.875       100.00       99.5     97.1
# 6                Open Area  ...  77.6  0.000         0.00       74.8     76.5
# 7         Commercial Place  ...  46.1  0.000         0.00        4.8     69.5
# 8              Residential  ...  67.8  0.844        25.00       78.8     77.1
# 9              Residential  ...  80.1  0.000         0.00       59.8     58.3
# 10        Commercial Place  ...  39.5  0.268        54.17       47.9     83.0
# 11        Commercial Place  ...  39.5  0.268        54.17       47.9     83.0
# 12        Commercial Place  ...  45.2  0.000         0.00       58.3     32.2
# 13        Commercial Place  ...  51.1  0.422        16.67       54.6     54.3
# 14        Commercial Place  ...  51.1  0.422        16.67       54.6     54.3
# 15        Commercial Place  ...  51.1  0.422        16.67       54.6     54.3
# 16                  Retail  ...  37.3  0.000         0.00       12.3     47.3
# 17  Public/Non-Residential  ...  56.1  0.000         0.00       57.4     50.5
# 18  Public/Non-Residential  ...  56.1  0.000         0.00       57.4     50.5
# 19  Public/Non-Residential  ...  56.1  0.000         0.00       57.4     50.5
#
#     windspeed windgust  visibility  snow              conditions
# 0        14.5     20.8         9.4   0.0  Rain, Partially cloudy
# 1        14.5     20.8         9.4   0.0  Rain, Partially cloudy
# 2        14.5     20.8         9.4   0.0  Rain, Partially cloudy
# 3        12.8     32.9         8.3   0.0  Rain, Partially cloudy
# 4        12.8     32.9         8.3   0.0  Rain, Partially cloudy
# 5        25.5     39.8         3.5   0.0          Rain, Overcast
# 6        10.0      NaN         9.9   0.0        Partially cloudy
# 7         6.5      NaN         9.8   0.0                   Clear
# 8        14.2     32.9         9.1   0.0  Rain, Partially cloudy
# 9         6.3     13.0         9.9   0.0        Partially cloudy
# 10       12.2     20.8         8.2   0.2  Rain, Partially cloudy
# 11       12.2     20.8         8.2   0.2  Rain, Partially cloudy
# 12       12.3     19.0         9.9   0.0        Partially cloudy
# 13       15.5     27.4         9.3   0.0  Rain, Partially cloudy
# 14       15.5     27.4         9.3   0.0  Rain, Partially cloudy
# 15       15.5     27.4         9.3   0.0  Rain, Partially cloudy
# 16        7.7     16.3         9.9   0.0                   Clear
# 17       17.9     31.1         9.9   0.0        Partially cloudy
# 18       17.9     31.1         9.9   0.0        Partially cloudy
# 19       17.9     31.1         9.9   0.0        Partially cloudy
#
# [20 rows x 31 columns]

# %%
df_complete['snow'] = df_complete['snow'].fillna(0)
df_complete.dropna(subset=['temp'], inplace=True)
df_complete.drop(columns=['windgust'], inplace=True)
df_complete.isna().sum()
# Out:
# YEAR                           0
# LOCATION                       0
# ZIP                            0
# LATITUDE_PUBLIC                0
# LONGITUDE_PUBLIC               0
# CMPD_PATROL_DIVISION         302
# NPA                            0
# DATE_REPORTED                  0
# LOCATION_TYPE_DESCRIPTION      0
# PLACE_TYPE_DESCRIPTION         0
# PLACE_DETAIL_DESCRIPTION       0
# HIGHEST_NIBRS_DESCRIPTION      0
# cluster                        0
# cluster_title                  0
# geometry                       0
# index_right                    0
# name                           0
# lat                            0
# lon                            0
# tempmax                        0
# tempmin                        0
# temp                           0
# precip                         0
# precipcover                    0
# cloudcover                     0
# humidity                       0
# windspeed                      0
# visibility                     0
# snow                           0
# conditions                     0
# dtype: int64

# %%
df_complete.to_csv("data\\crime_with_weather.csv", index=False)

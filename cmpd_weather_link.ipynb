# %%
import pandas as pd
import numpy as np
import requests
import time
import os
import re
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("WEATHER_API_KEY")
df = pd.read_csv("data\\crime_within_station_walksheds.csv")

# %%
def fetch_daily_weather(lat, lon, date_str, unitGroup="us"):
    """
    Returns a dict with daily summary weather for a single (lat, lon, date).
    """
    base = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline"
    location = f"{lat},{lon}"
    url = f"{base}/{location}/{date_str}"

    params = {
        "key": API_KEY,
        "contentType": "json",
        "unitGroup": unitGroup,
        "include": "days",
        # Request only what you need (plus datetime for safety)
        "elements": ",".join([
            "datetime",
            "tempmax",
            "tempmin",
            "temp",
            "precip",
            "precipcover",
            "cloudcover",
            "humidity",
            "windspeed",
            "visibility",
            "snow",
            "conditions"
])

    }

    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()

    # Daily summary lives in data["days"][0] for a single-day query
    day = data["days"][0]
    return {
        "DATE_REPORTED": day.get("datetime"),
        "tempmax": day.get("tempmax"),
        "tempmin": day.get("tempmin"),
        "temp": day.get("temp"),
        "precip": day.get("precip"),
        "precipcover": day.get("precipcover"),
        "cloudcover": day.get("cloudcover"),
        "humidity": day.get("humidity"),
        "windspeed": day.get("windspeed"),
        "visibility": day.get("visibility"),
        "snow": day.get("snow"),
        "conditions": day.get("conditions"),
    }

# %%
df["date"] = pd.to_datetime(df["date"]).dt.strftime("%Y-%m-%d")

# Optional: reduce unique calls by rounding coords
df['lat'] = df['LATITUDE_PUBLIC']
df['lon'] = df['LONGITUDE_PUBLIC']
df["LATITUDE_PUBLIC"] = df["LATITUDE_PUBLIC"].round(2)
df["LONGITUDE_PUBLIC"] = df["LONGITUDE_PUBLIC"].round(2)

keys = df[["date", "LATITUDE_PUBLIC", "LONGITUDE_PUBLIC"]].drop_duplicates()

# %%
weather_rows = []
for i, row in keys.iterrows():
    try:
        w = fetch_daily_weather(row["LATITUDE_PUBLIC"], row["LONGITUDE_PUBLIC"], row["date"])
        w["LATITUDE_PUBLIC"] = row["LATITUDE_PUBLIC"]
        w["LONGITUDE_PUBLIC"] = row["LONGITUDE_PUBLIC"]
        weather_rows.append(w)
    except Exception as e:
        # Keep going; log failures
        print(e)
        weather_rows.append({
            "INCIDENT_REPORT_ID": row["INCIDENT_REPORT_ID"],
            "LATITUDE_PUBLIC": row["LATITUDE_PUBLIC"],
            "LONGITUDE_PUBLIC": row["LONGITUDE_PUBLIC"],
            "lat": row["lat"],
            "lon": row["lon"],
            "tempmax": None,
            "tempmin": None,
            "temp": None,
            "precip": None,
            "precipcover": None,
            "cloudcover": None,
            "humidity": None,
            "windspeed": None,
            "visibility": None,
            "snow": None,
            "conditions": None,
            "error": str(e)[:200]
        })

    # simple rate-limiting to be safe
    time.sleep(0.1)
    if i % 100 == 0:
        print(i)

weather_df = pd.DataFrame(weather_rows)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1100
# 1200
# 1300
# 1400
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3800
# 4200
# 4400
# 4500
# 4700
# 4800
# 5000
# 5100
# 5300
# 5400
# 5500
# 5600
# 5700
# 6100
# 6200
# 6300
# 6600
# 6700
# 6800
# 6900
# 7000
# 7200
# 7700
# 7800
# 7900
# 8100
# 8200
# 8400
# 8600
# 8700
# 8900
# 9000
# 9200
# 9300
# 9500
# 9800
# 10400
# 10500
# 10700
# 10900
# 11000
# 11100
# 11400
# 11500
# 11700
# 11800
# 12000
# 12100
# 13500
# 13700
# 13800
# 14200
# 14300
# 14600
# 14900
# 15800
# 16300
# 16500
# 16700
# 16900
# 17200
# 17600
# 17700
# 18000
# 18200
# 18500
# 18600
# 19400
# 19900
# 20000
# 20100
# 20200
# 20400
# 20500
# 20600
# 21700
# 22200
# 22300
# 22400
# 22700
# 22900
# 23500
# 23800
# 23900
# 24100
# 24300
# 24500
# 24700
# 25000
# 25400
# 25800
# 26900
# 27400
# 28000
# 28300
# 28600
# 29900
# 30200
# 30700
# 31500
# 31700
# 32000
# 32400
# 32700
# 33600
# 34500

# %%
weather_df.rename(columns={"DATE_REPORTED": "date"}, inplace=True)

# %%
df_complete = df.merge(weather_df, on=["date", "LATITUDE_PUBLIC", "LONGITUDE_PUBLIC"], how="left")

# %%
df_complete['lat'] = df['lat']
df_complete['lon'] = df['lon']
df_complete.isna().sum()
# Out:
# INCIDENT_REPORT_ID             0
# LOCATION                       0
# ZIP                            0
# LATITUDE_PUBLIC                0
# LONGITUDE_PUBLIC               0
# CMPD_PATROL_DIVISION         138
# NPA                            0
# LOCATION_TYPE_DESCRIPTION      0
# PLACE_TYPE_DESCRIPTION         0
# PLACE_DETAIL_DESCRIPTION       0
# HIGHEST_NIBRS_DESCRIPTION      0
# date                           0
# year                           0
# hour                           0
# day_type                       0
# cluster                        0
# cluster_title                  0
# geometry                       0
# nearest_station                0
# station_list                   0
# lat                            0
# lon                            0
# tempmax                        0
# tempmin                        0
# temp                           0
# precip                         0
# precipcover                    0
# cloudcover                     0
# humidity                       0
# windspeed                      0
# visibility                     0
# snow                           0
# conditions                     0
# dtype: int64

# %%
df_complete.head(20)
# Out:
#    INCIDENT_REPORT_ID            LOCATION    ZIP  LATITUDE_PUBLIC  \
# 0    20220704-0820-00    300 S BREVARD ST  28202            35.22
# 1    20230104-1325-00      400 S TRYON ST  28202            35.22
# 2    20180916-0854-01      900 SPINDLE ST  28206            35.23
# 3    20180523-1548-04      600 S TRYON ST  28202            35.22
# 4    20191125-1133-02      200 E BLAND ST  28203            35.22
# 5    20230428-1602-03     600 N CHURCH ST  28202            35.23
# 6    20240703-0652-00   500 N DAVIDSON ST  28202            35.23
# 7    20260118-0023-00  500 NORTH ELLIS LN  28202            35.23
# 8    20240229-1100-01       1300 SOUTH BV  28203            35.22
# 9    20170215-2050-03    300 S COLLEGE ST  28202            35.22
# 10   20260112-0720-00       2000 SOUTH BV  28203            35.21
# 11   20221109-0754-01    200 N COLLEGE ST  28202            35.23
# 12   20240302-1932-04   600 S CALDWELL ST  28202            35.22
# 13   20170120-1656-01      600 E TRADE ST  28202            35.22
# 14   20200618-2050-06      100 N TRYON ST  28202            35.23
# 15   20170418-1759-01      2000 EUCLID AV  28213            35.21
# 16   20180823-0715-01      300 S TRYON ST  28202            35.23
# 17   20230513-0556-01     300 S CHURCH ST  28202            35.23
# 18   20231008-1323-00        300 E 6TH ST  28202            35.23
# 19   20180904-1921-00      300 E TRADE ST  28202            35.23
#
#     LONGITUDE_PUBLIC CMPD_PATROL_DIVISION  NPA LOCATION_TYPE_DESCRIPTION  \
# 0             -80.84              Central  476                  Outdoors
# 1             -80.85              Central  476                  Outdoors
# 2             -80.83              Central  476                   Indoors
# 3             -80.85              Central  476                  Outdoors
# 4             -80.85              Central    3                     Other
# 5             -80.84              Central  476              Parking Deck
# 6             -80.83              Central  476                   Indoors
# 7             -80.84              Central  476                   Indoors
# 8             -80.85              Central    3                   Indoors
# 9             -80.84              Central  476                   Indoors
# 10            -80.86              Central    3                   Indoors
# 11            -80.84              Central  476                  Outdoors
# 12            -80.85              Central  476                   Indoors
# 13            -80.84              Central  476                   Indoors
# 14            -80.84              Central  476                  Outdoors
# 15            -80.86           Providence    3                   Indoors
# 16            -80.85              Central  476                  Outdoors
# 17            -80.85              Central  476              Parking Deck
# 18            -80.84              Central  476              Parking Deck
# 19            -80.84              Central  476                  Outdoors
#
#     PLACE_TYPE_DESCRIPTION           PLACE_DETAIL_DESCRIPTION  ... tempmin  \
# 0                Open Area                     Street/Highway  ...    73.0
# 1         Commercial Place           Other - Commercial Place  ...    57.8
# 2              Residential                  Private Residence  ...    71.9
# 3                Open Area                  Construction Site  ...    71.1
# 4         Commercial Place               Bar/Tavern/Nightclub  ...    32.1
# 5              Residential       Apartment/Duplex Private Res  ...    60.6
# 6              Residential       Apartment/Duplex Private Res  ...    69.4
# 7         Commercial Place       Restaurant/Diner/Coffee Shop  ...    28.7
# 8         Commercial Place           Other - Commercial Place  ...    38.0
# 9         Commercial Place       Restaurant/Diner/Coffee Shop  ...    43.4
# 10                  Retail                      Shopping Mall  ...    26.7
# 11  Public/Non-Residential  Dock/Wharf/Freight/Modal Terminal  ...    46.1
# 12        Commercial Place                        Hotel/Motel  ...    43.0
# 13        Commercial Place             Bus - Charter/Tour Bus  ...    51.3
# 14        Commercial Place           Other - Commercial Place  ...    64.1
# 15             Residential                  Private Residence  ...    64.1
# 16  Public/Non-Residential     Other - Public/Non-Residential  ...    65.7
# 17        Commercial Place           Other - Commercial Place  ...    68.9
# 18               Open Area                  Other - Open Area  ...    43.1
# 19        Commercial Place                      Stadium/Arena  ...    73.0
#
#     temp  precip  precipcover cloudcover  humidity windspeed visibility snow  \
# 0   80.4   0.011         8.33       53.2      76.0      14.5        9.4  0.0
# 1   61.3   1.307        50.00       89.5      93.3      12.8        8.3  0.0
# 2   72.9   3.875       100.00       99.5      97.1      25.5        3.5  0.0
# 3   77.6   0.000         0.00       74.8      76.5      10.0        9.9  0.0
# 4   46.1   0.000         0.00        4.8      69.5       6.5        9.8  0.0
# 5   67.8   0.844        25.00       78.8      77.1      14.2        9.1  0.0
# 6   80.1   0.000         0.00       59.8      58.3       6.3        9.9  0.0
# 7   39.5   0.268        54.17       47.9      83.0      12.2        8.2  0.2
# 8   45.2   0.000         0.00       58.3      32.2      12.3        9.9  0.0
# 9   51.1   0.422        16.67       54.6      54.3      15.5        9.3  0.0
# 10  37.3   0.000         0.00       12.3      47.3       7.7        9.9  0.0
# 11  56.1   0.000         0.00       57.4      50.5      17.9        9.9  0.0
# 12  53.3   0.023         8.33       83.8      83.3      11.0        7.0  0.0
# 13  55.5   0.082        12.50       72.3      80.5      14.0        8.1  0.0
# 14  70.3   0.021        16.67       72.2      76.2      10.7        9.8  0.0
# 15  67.4   0.000         0.00       81.7      67.1      14.0        9.9  0.0
# 16  73.1   0.000         0.00       25.3      57.1      12.7        9.3  0.0
# 17  74.5   0.151         8.33       88.1      75.5       9.2        9.2  0.0
# 18  54.6   0.000         0.00       14.6      52.8       9.1        9.9  0.0
# 19  80.6   0.173        12.50       67.0      78.7       9.4        9.8  0.0
#
#                 conditions
# 0   Rain, Partially cloudy
# 1   Rain, Partially cloudy
# 2           Rain, Overcast
# 3         Partially cloudy
# 4                    Clear
# 5   Rain, Partially cloudy
# 6         Partially cloudy
# 7   Rain, Partially cloudy
# 8         Partially cloudy
# 9   Rain, Partially cloudy
# 10                   Clear
# 11        Partially cloudy
# 12  Rain, Partially cloudy
# 13  Rain, Partially cloudy
# 14  Rain, Partially cloudy
# 15        Partially cloudy
# 16        Partially cloudy
# 17  Rain, Partially cloudy
# 18                   Clear
# 19  Rain, Partially cloudy
#
# [20 rows x 33 columns]

# %%
df_complete['snow'] = df_complete['snow'].fillna(0)
df_complete.dropna(subset=['temp'], inplace=True)
df_complete.isna().sum()
# Out:
# INCIDENT_REPORT_ID             0
# LOCATION                       0
# ZIP                            0
# LATITUDE_PUBLIC                0
# LONGITUDE_PUBLIC               0
# CMPD_PATROL_DIVISION         138
# NPA                            0
# LOCATION_TYPE_DESCRIPTION      0
# PLACE_TYPE_DESCRIPTION         0
# PLACE_DETAIL_DESCRIPTION       0
# HIGHEST_NIBRS_DESCRIPTION      0
# date                           0
# year                           0
# hour                           0
# day_type                       0
# cluster                        0
# cluster_title                  0
# geometry                       0
# nearest_station                0
# station_list                   0
# lat                            0
# lon                            0
# tempmax                        0
# tempmin                        0
# temp                           0
# precip                         0
# precipcover                    0
# cloudcover                     0
# humidity                       0
# windspeed                      0
# visibility                     0
# snow                           0
# conditions                     0
# dtype: int64

# %%
df_complete.to_csv("data\\crime_with_weather.csv", index=False)
